# %% [markdown]
# # Final Assignment: Segmenting and Clustering Neighborhoods in Toronto

# %% [markdown]
# First, let's import required libraries

# %%
import pandas as pd
import numpy as np
from geopy.geocoders import Nominatim
import folium
import requests
from sklearn.cluster import KMeans
from sklearn.preprocessing import Normalizer
import matplotlib.cm as cm
import matplotlib.colors as colors

# %% [markdown]
# Now, let's import list of demographic data on each Toronto neighborhood taken from the Canadian census.

# %%
data = pd.read_csv('toronto_clustering-census.csv', header = None, names = ['Neighborhood', 'Income', '2nd Language Proportion', '2nd Language', 'Lat', 'Lon'])
data.set_index('Neighborhood', inplace=True)
data.head()
# Out:
#                            Income  2nd Language Proportion 2nd Language  Lat  \
# Neighborhood
# Regent Park/Trefann Court   19521                    0.105      Bengali  NaN
# Oakridge                    21155                    0.126      Bengali  NaN
# Crescent Town               23021                    0.181      Bengali  NaN
# Leaside                     82670                    0.004    Bulgarian  NaN
# The Beaches                 67536                    0.007    Cantonese  NaN
#
#                            Lon
# Neighborhood
# Regent Park/Trefann Court  NaN
# Oakridge                   NaN
# Crescent Town              NaN
# Leaside                    NaN
# The Beaches                NaN

# %% [markdown]
# Let's retrieve latitude and longtitude of each neighborhood using geopy library.

# %%
geolocator = Nominatim(user_agent='Coursera Project')
city = ', Toronto'

for s in data.index:
    location = geolocator.geocode(s + city)
    if location != None:
        data.loc[s, 'Lat'] = location.raw['lat']
        data.loc[s, 'Lon'] = location.raw['lon']

data['Lat'] = data['Lat'].astype(float)
data['Lon'] = data['Lon'].astype(float)
data.head()
# Out:
#                            Income  2nd Language Proportion 2nd Language  \
# Neighborhood
# Regent Park/Trefann Court   19521                    0.105      Bengali
# Oakridge                    21155                    0.126      Bengali
# Crescent Town               23021                    0.181      Bengali
# Leaside                     82670                    0.004    Bulgarian
# The Beaches                 67536                    0.007    Cantonese
#
#                                  Lat        Lon
# Neighborhood
# Regent Park/Trefann Court  43.659279 -79.366135
# Oakridge                   43.697174 -79.274823
# Crescent Town              43.695403 -79.293099
# Leaside                    43.704798 -79.368090
# The Beaches                43.671024 -79.296712

# %% [markdown]
# We can inspect all the neighborhoods on the map of Toronto.

# %%
# Create map of Toronto
mapToronto = folium.Map(location=[43.7, -79.384293], zoom_start=11)

# Add markers to map
for lat, lng, label in zip(data['Lat'], data['Lon'], data.index):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(mapToronto)  
    
mapToronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Let's construct our features. First, let's filter proportions for chinese languages.

# %%
data.loc[~data['2nd Language'].isin(['Cantonese', 'Mandarin', 'Unspecified Chinese']), '2nd Language Proportion'] = 0
data.drop('2nd Language', axis=1, inplace = True)
data.rename(columns = {'2nd Language Proportion' : 'Chinese Language Proportion'}, inplace = True)
data.head()
# Out:
#                            Income  Chinese Language Proportion        Lat  \
# Neighborhood
# Regent Park/Trefann Court   19521                        0.000  43.659279
# Oakridge                    21155                        0.000  43.697174
# Crescent Town               23021                        0.000  43.695403
# Leaside                     82670                        0.000  43.704798
# The Beaches                 67536                        0.007  43.671024
#
#                                  Lon
# Neighborhood
# Regent Park/Trefann Court -79.366135
# Oakridge                  -79.274823
# Crescent Town             -79.293099
# Leaside                   -79.368090
# The Beaches               -79.296712

# %% [markdown]
# Let's enter our Foursquare API credentials.

# %%
CLIENT_ID = 'REDACTED' #Foursquare ID
CLIENT_SECRET = 'REDACTED' #Foursquare Secret
VERSION = '20180604'
LIMIT = 50
search_query = 'Food'

# %% [markdown]
# Now, we will create a fuinction that retrieves nearby venues for specified location.

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name + ' ', end='')
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&query={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT,
            search_query)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# Let's use this function with our dataset.

# %%
toronto_food = getNearbyVenues(data.index, data['Lat'], data['Lon'])
# Out:
# Regent Park/Trefann Court Oakridge Crescent Town Leaside The Beaches Upper Beaches Bridle Path Kensington Market Alexandra Park Agincourt Cliffside West Rouge Steeles Milliken East Danforth Riverdale Willowdale Bayview Village Bayview Woods Steeles Leslieville Cricket Club Ledbury Park Port Union Rouge Hill Maryvale Clairlea Wexford Wilson Heights Ionview Lawrence Manor St. James Town Lawrence Park South Hill Moore Park Chaplin Estates Yorkville Bedford Park Old East York Bracondale Hill The Danforth Woburn Fort York/Liberty Village Humberlea Downsview Maple Leaf Lawrence Heights Humber Summit The Queensway Richview York University Heights Pelmo Park Glen Park Financial District Casa Loma Princess Gardens York Mills Islington Six Points Port Lands Henry Farm Bay Street Corridor Toronto Islands Guildwood Davisville Graydon Hall Lansing Centennial Parkdale High Park North Swansea Markland Wood Mimico Roncesvalles Long Branch New Toronto Sunnylea Alderwood Fashion District Fairbank Silverthorn Christie Pits Junction Triangle Dovercourt Park Trinity Bellwoods Dufferin Grove Carleton Village Davenport Little Italy Earlscourt Harwood Wallace Emerson Brockton Wychwood Little Portugal Eringate Lambton Niagara Harbord Village The Junction Seaton Village Smithfield Humberwood Thistletown Deer Park Allenby Forest Hill Branson Westminster Newtonbrook Armour Heights Bathurst Manor Lytton Park Eatonville Kingsview Village The Annex Church and Wellesley Corktown Humber Heights Amesbury The Elms Weston Mount Dennis Caribou Park Cliffcrest Scarborough City Centre Morningside Scarborough Village Malvern Rouge West Hill Bendale Scarborough Junction Highland Creek Dorset Park Eglinton East The Kingsway Westmount Runnymede West Deane Park Bloor West Village Humber Valley Village Old Mill/Baby Point Birch Cliff Rosedale Summerhill Cabbagetown North York City Centre Tam O'Shanter Sullivan Pleasant View Hillcrest L'Amoreaux Grange Park Harbourfront/ CityPlace Hoggs Hollow Garden District Parkwoods Don Mills Banbury Discovery District Parkway Forest Don Valley Village Thorncliffe Park O'Connor Parkview Victoria Village Flemingdon Park Elia (Jane and Finch)

# %% [markdown]
# Let's add a column that would represent the number of chinese food places for each neighborhood.

# %%
chinese_food = toronto_food.loc[toronto_food['Venue Category'].isin({'Asian Restaurant', 'Chinese Restaurant', 'Dim Sum Restaurant', 'Dumpling Restaurant', 'Noodle House'})].groupby('Neighborhood').count()
chinese_food.drop(['Neighborhood Latitude', 'Neighborhood Longitude', 'Venue', 'Venue Latitude', 'Venue Longitude'], axis = 1, inplace = True)
chinese_food.rename(columns = {'Venue Category' : 'Chinese Food Count'}, inplace = True)
data = data.merge(chinese_food, left_index = True, right_index = True, how='left')
data['Chinese Food Count'] = data['Chinese Food Count'].apply(lambda x: 0 if np.isnan(x) else x)
data.head(10)
# Out:
#                            Income  Chinese Language Proportion        Lat  \
# Neighborhood
# Regent Park/Trefann Court   19521                        0.000  43.659279
# Oakridge                    21155                        0.000  43.697174
# Crescent Town               23021                        0.000  43.695403
# Leaside                     82670                        0.000  43.704798
# The Beaches                 67536                        0.007  43.671024
# Upper Beaches               44346                        0.007  43.671024
# Bridle Path                314107                        0.120  43.735400
# Kensington Market           23335                        0.143  43.655214
# Alexandra Park              19687                        0.179  43.650758
# Agincourt                   25750                        0.193  43.785353
#
#                                  Lon  Chinese Food Count
# Neighborhood
# Regent Park/Trefann Court -79.366135                 1.0
# Oakridge                  -79.274823                 0.0
# Crescent Town             -79.293099                 0.0
# Leaside                   -79.368090                 0.0
# The Beaches               -79.296712                 1.0
# Upper Beaches             -79.296712                 1.0
# Bridle Path               -79.370883                 0.0
# Kensington Market         -79.402260                 3.0
# Alexandra Park            -79.404298                 4.0
# Agincourt                 -79.278549                11.0

# %% [markdown]
# Now, let's add a column that would represent the total number of food venues for each neighborhood.

# %%
food_count = toronto_food.groupby('Neighborhood').count()
food_count.drop(['Neighborhood Latitude', 'Neighborhood Longitude', 'Venue', 'Venue Latitude', 'Venue Longitude'], axis = 1, inplace = True)
food_count.rename(columns = {'Venue Category' : 'Total Food Count'}, inplace = True)
data = data.merge(food_count, left_index = True, right_index = True, how='left')
data['Total Food Count'] = data['Total Food Count'].apply(lambda x: 0 if np.isnan(x) else x)
data.head(10)
# Out:
#                            Income  Chinese Language Proportion        Lat  \
# Neighborhood
# Regent Park/Trefann Court   19521                        0.000  43.659279
# Oakridge                    21155                        0.000  43.697174
# Crescent Town               23021                        0.000  43.695403
# Leaside                     82670                        0.000  43.704798
# The Beaches                 67536                        0.007  43.671024
# Upper Beaches               44346                        0.007  43.671024
# Bridle Path                314107                        0.120  43.735400
# Kensington Market           23335                        0.143  43.655214
# Alexandra Park              19687                        0.179  43.650758
# Agincourt                   25750                        0.193  43.785353
#
#                                  Lon  Chinese Food Count  Total Food Count
# Neighborhood
# Regent Park/Trefann Court -79.366135                 1.0              28.0
# Oakridge                  -79.274823                 0.0               4.0
# Crescent Town             -79.293099                 0.0               0.0
# Leaside                   -79.368090                 0.0               5.0
# The Beaches               -79.296712                 1.0              26.0
# Upper Beaches             -79.296712                 1.0              26.0
# Bridle Path               -79.370883                 0.0               1.0
# Kensington Market         -79.402260                 3.0              50.0
# Alexandra Park            -79.404298                 4.0              50.0
# Agincourt                 -79.278549                11.0              18.0

# %% [markdown]
# Let's normalize the data before applying k-means clustering algorithm.

# %%
clustering = data.reset_index().drop(['Neighborhood', 'Lat', 'Lon'], 1)
transformer = Normalizer().fit_transform(clustering)

# %% [markdown]
# Now we can aplly the k-means clustering algorithm.

# %%
kclusters = 4
kmeans = KMeans(n_clusters=kclusters, random_state=10).fit(transformer)

data_clustered = data
data_clustered['Cluster Labels'] = kmeans.labels_
data_clustered.head(10)
# Out:
#                            Income  Chinese Language Proportion        Lat  \
# Neighborhood
# Regent Park/Trefann Court   19521                        0.000  43.659279
# Oakridge                    21155                        0.000  43.697174
# Crescent Town               23021                        0.000  43.695403
# Leaside                     82670                        0.000  43.704798
# The Beaches                 67536                        0.007  43.671024
# Upper Beaches               44346                        0.007  43.671024
# Bridle Path                314107                        0.120  43.735400
# Kensington Market           23335                        0.143  43.655214
# Alexandra Park              19687                        0.179  43.650758
# Agincourt                   25750                        0.193  43.785353
#
#                                  Lon  Chinese Food Count  Total Food Count  \
# Neighborhood
# Regent Park/Trefann Court -79.366135                 1.0              28.0
# Oakridge                  -79.274823                 0.0               4.0
# Crescent Town             -79.293099                 0.0               0.0
# Leaside                   -79.368090                 0.0               5.0
# The Beaches               -79.296712                 1.0              26.0
# Upper Beaches             -79.296712                 1.0              26.0
# Bridle Path               -79.370883                 0.0               1.0
# Kensington Market         -79.402260                 3.0              50.0
# Alexandra Park            -79.404298                 4.0              50.0
# Agincourt                 -79.278549                11.0              18.0
#
#                            Cluster Labels
# Neighborhood
# Regent Park/Trefann Court               1
# Oakridge                                0
# Crescent Town                           0
# Leaside                                 0
# The Beaches                             2
# Upper Beaches                           2
# Bridle Path                             0
# Kensington Market                       3
# Alexandra Park                          3
# Agincourt                               2

# %% [markdown]
# Let's show our clusters on the map of Toronto.

# %%
# create map
map_clusters = folium.Map(location=[43.7, -79.384293], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(data_clustered['Lat'], data_clustered['Lon'], data_clustered.index, data_clustered['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Finally, let's inspect our clusters and make the conclusions.

# %% [markdown]
# Cluster 1:

# %%
data_clustered.loc[data_clustered['Cluster Labels'] == 0]
# Out:
#                         Income  Chinese Language Proportion        Lat  \
# Neighborhood
# Oakridge                 21155                        0.000  43.697174
# Crescent Town            23021                        0.000  43.695403
# Leaside                  82670                        0.000  43.704798
# Bridle Path             314107                        0.120  43.735400
# Cliffside                32701                        0.023  43.711170
# West Rouge               44605                        0.028  43.785963
# Steeles                  26660                        0.237  43.816178
# Bayview Village          46752                        0.084  43.769197
# Bayview Woods Steeles    41485                        0.093  43.798127
# Cricket Club            104362                        0.000  43.739826
# Ledbury Park             83853                        0.000  43.720716
# Port Union               48117                        0.000  43.775504
# Rouge Hill               32858                        0.000  43.780271
# Maryvale                 30944                        0.000  43.759051
# Clairlea                 33392                        0.000  43.708823
# Wilson Heights           37978                        0.000  43.740519
# Ionview                  25078                        0.000  43.735990
# Lawrence Manor           36361                        0.000  43.722079
# Lawrence Park           214110                        0.000  43.729199
# South Hill              120453                        0.000  43.677926
# Moore Park              154825                        0.000  43.690388
# Chaplin Estates          81288                        0.000  43.702598
# Bedford Park             80827                        0.000  43.737388
# Bracondale Hill          41605                        0.000  43.676125
# The Danforth             44979                        0.000  43.686360
# Woburn                   26190                        0.000  43.759824
# Humberlea                30907                        0.000  43.721317
# Downsview                26751                        0.000  43.749299
# Maple Leaf               27611                        0.000  43.712277
# Humber Summit            26117                        0.000  43.760078
# ...                        ...                          ...        ...
# Morningside              27139                        0.000  43.782601
# Scarborough Village      24413                        0.000  43.743742
# Malvern                  25677                        0.000  43.809196
# Rouge                    29230                        0.000  43.804930
# Bendale                  29723                        0.000  43.753520
# Scarborough Junction     25405                        0.000  43.716049
# Highland Creek           33640                        0.000  43.790117
# Dorset Park              26525                        0.000  43.752847
# Eglinton East            25307                        0.000  43.739622
# The Kingsway            110944                        0.000  43.647381
# Westmount                35183                        0.000  43.693640
# Runnymede                42635                        0.000  43.665580
# West Deane Park          41582                        0.000  43.663199
# Humber Valley Village    80618                        0.000  43.666472
# Old Mill/Baby Point     110372                        0.000  43.655874
# Birch Cliff              48965                        0.009  43.702112
# Rosedale                213941                        0.010  43.676453
# Summerhill               88937                        0.011  43.681678
# Tam O'Shanter Sullivan   27717                        0.126  43.768951
# Pleasant View            29250                        0.127  43.787048
# Hoggs Hollow            222560                        0.024  43.741534
# Parkwoods                34811                        0.034  43.761124
# Don Mills                47515                        0.039  43.737178
# Banbury                  92319                        0.051  43.742796
# Parkway Forest           24333                        0.085  43.771660
# Don Valley Village       30442                        0.097  43.792673
# O'Connor Parkview        33517                        0.000  43.707060
# Victoria Village         29657                        0.000  43.732658
# Flemingdon Park          23471                        0.000  43.718432
# Elia (Jane and Finch)    22691                        0.000  43.762640
#
#                               Lon  Chinese Food Count  Total Food Count  \
# Neighborhood
# Oakridge               -79.274823                 0.0               4.0
# Crescent Town          -79.293099                 0.0               0.0
# Leaside                -79.368090                 0.0               5.0
# Bridle Path            -79.370883                 0.0               1.0
# Cliffside              -79.248177                 0.0               6.0
# West Rouge             -79.130756                 0.0               1.0
# Steeles                -79.314538                 0.0               0.0
# Bayview Village        -79.376662                 0.0               6.0
# Bayview Woods Steeles  -79.382973                 0.0               0.0
# Cricket Club           -79.418975                 0.0               5.0
# Ledbury Park           -79.422391                 0.0               0.0
# Port Union             -79.134976                 0.0               0.0
# Rouge Hill             -79.130499                 0.0               0.0
# Maryvale               -79.310230                 0.0               7.0
# Clairlea               -79.295986                 0.0               6.0
# Wilson Heights         -79.440017                 1.0               6.0
# Ionview                -79.276515                 1.0               2.0
# Lawrence Manor         -79.437507                 0.0               1.0
# Lawrence Park          -79.403252                 2.0              35.0
# South Hill             -79.405767                 1.0              17.0
# Moore Park             -79.383297                 0.0               2.0
# Chaplin Estates        -79.403270                 1.0              20.0
# Bedford Park           -79.410925                 0.0               1.0
# Bracondale Hill        -79.428000                 0.0               5.0
# The Danforth           -79.300316                 1.0              16.0
# Woburn                 -79.225291                 0.0               9.0
# Humberlea              -79.533160                 0.0               3.0
# Downsview              -79.462248                 0.0               4.0
# Maple Leaf             -79.490198                 0.0               2.0
# Humber Summit          -79.571760                 0.0               4.0
# ...                           ...                 ...               ...
# Morningside            -79.204958                 0.0               4.0
# Scarborough Village    -79.211632                 2.0               4.0
# Malvern                -79.221701                 0.0               5.0
# Rouge                  -79.165837                 1.0               3.0
# Bendale                -79.255336                 1.0               4.0
# Scarborough Junction   -79.260703                 1.0               4.0
# Highland Creek         -79.173334                 0.0               0.0
# Dorset Park            -79.282067                 2.0               6.0
# Eglinton East          -79.232290                 0.0               4.0
# The Kingsway           -79.511333                 1.0              22.0
# Westmount              -79.521043                 1.0               3.0
# Runnymede              -79.482108                 0.0              13.0
# West Deane Park        -79.568568                 0.0               0.0
# Humber Valley Village  -79.524314                 0.0               1.0
# Old Mill/Baby Point    -79.496494                 0.0               0.0
# Birch Cliff            -79.260091                 0.0               0.0
# Rosedale               -79.388434                 1.0              14.0
# Summerhill             -79.390504                 2.0              22.0
# Tam O'Shanter Sullivan -79.301871                 2.0               4.0
# Pleasant View          -79.333714                 0.0              10.0
# Hoggs Hollow           -79.402878                 0.0               8.0
# Parkwoods              -79.324059                 1.0               5.0
# Don Mills              -79.343451                 0.0              14.0
# Banbury                -79.369957                 0.0               0.0
# Parkway Forest         -79.342663                 0.0               6.0
# Don Valley Village     -79.354722                 1.0               8.0
# O'Connor Parkview      -79.311630                 0.0               7.0
# Victoria Village       -79.311189                 1.0               4.0
# Flemingdon Park        -79.333204                 1.0               7.0
# Elia (Jane and Finch)  -79.517893                 0.0               1.0
#
#                         Cluster Labels
# Neighborhood
# Oakridge                             0
# Crescent Town                        0
# Leaside                              0
# Bridle Path                          0
# Cliffside                            0
# West Rouge                           0
# Steeles                              0
# Bayview Village                      0
# Bayview Woods Steeles                0
# Cricket Club                         0
# Ledbury Park                         0
# Port Union                           0
# Rouge Hill                           0
# Maryvale                             0
# Clairlea                             0
# Wilson Heights                       0
# Ionview                              0
# Lawrence Manor                       0
# Lawrence Park                        0
# South Hill                           0
# Moore Park                           0
# Chaplin Estates                      0
# Bedford Park                         0
# Bracondale Hill                      0
# The Danforth                         0
# Woburn                               0
# Humberlea                            0
# Downsview                            0
# Maple Leaf                           0
# Humber Summit                        0
# ...                                ...
# Morningside                          0
# Scarborough Village                  0
# Malvern                              0
# Rouge                                0
# Bendale                              0
# Scarborough Junction                 0
# Highland Creek                       0
# Dorset Park                          0
# Eglinton East                        0
# The Kingsway                         0
# Westmount                            0
# Runnymede                            0
# West Deane Park                      0
# Humber Valley Village                0
# Old Mill/Baby Point                  0
# Birch Cliff                          0
# Rosedale                             0
# Summerhill                           0
# Tam O'Shanter Sullivan               0
# Pleasant View                        0
# Hoggs Hollow                         0
# Parkwoods                            0
# Don Mills                            0
# Banbury                              0
# Parkway Forest                       0
# Don Valley Village                   0
# O'Connor Parkview                    0
# Victoria Village                     0
# Flemingdon Park                      0
# Elia (Jane and Finch)                0
#
# [111 rows x 7 columns]

# %% [markdown]
# Cluster 2:

# %%
data_clustered.loc[data_clustered['Cluster Labels'] == 1]
# Out:
#                            Income  Chinese Language Proportion        Lat  \
# Neighborhood
# Regent Park/Trefann Court   19521                        0.000  43.659279
# Milliken                    25243                        0.266  43.823217
# Leslieville                 30886                        0.094  43.662700
# Fort York/Liberty Village   46086                        0.000  43.642155
# Lawrence Heights            29867                        0.000  43.722778
# York University Heights     24432                        0.000  43.770226
# Bay Street Corridor         40598                        0.096  43.665275
# Parkdale                    26314                        0.000  43.637178
# Junction Triangle           28067                        0.000  43.665478
# Trinity Bellwoods           31106                        0.000  43.647627
# Dufferin Grove              27961                        0.000  43.653616
# Davenport                   28335                        0.000  43.674928
# Little Italy                31231                        0.000  43.655208
# Little Portugal             29224                        0.000  43.649631
# Niagara                     44611                        0.000  43.644658
# The Junction                34906                        0.000  43.665478
# Church and Wellesley        37653                        0.000  43.665524
# North York City Centre      34330                        0.101  43.768486
# Hillcrest                   33465                        0.139  43.653963
# Grange Park                 35277                        0.148  43.652147
# Garden District             37614                        0.030  43.656502
# Discovery District          41998                        0.065  43.657556
#
#                                  Lon  Chinese Food Count  Total Food Count  \
# Neighborhood
# Regent Park/Trefann Court -79.366135                 1.0              28.0
# Milliken                  -79.301523                15.0              38.0
# Leslieville               -79.332815                 0.0              33.0
# Fort York/Liberty Village -79.410934                 4.0              49.0
# Lawrence Heights          -79.450933                 2.0              42.0
# York University Heights   -79.502180                 0.0              23.0
# Bay Street Corridor       -79.387528                 1.0              45.0
# Parkdale                  -79.436004                 3.0              28.0
# Junction Triangle         -79.470352                 0.0              35.0
# Trinity Bellwoods         -79.413879                 1.0              37.0
# Dufferin Grove            -79.426389                 0.0              36.0
# Davenport                 -79.393868                 2.0              45.0
# Little Italy              -79.414877                 2.0              50.0
# Little Portugal           -79.431433                 0.0              29.0
# Niagara                   -79.409207                 5.0              50.0
# The Junction              -79.470352                 0.0              35.0
# Church and Wellesley      -79.383801                 1.0              50.0
# North York City Centre    -79.414026                 1.0              34.0
# Hillcrest                 -79.387207                 4.0              42.0
# Grange Park               -79.392265                 7.0              50.0
# Garden District           -79.377128                 1.0              50.0
# Discovery District        -79.389480                 6.0              50.0
#
#                            Cluster Labels
# Neighborhood
# Regent Park/Trefann Court               1
# Milliken                                1
# Leslieville                             1
# Fort York/Liberty Village               1
# Lawrence Heights                        1
# York University Heights                 1
# Bay Street Corridor                     1
# Parkdale                                1
# Junction Triangle                       1
# Trinity Bellwoods                       1
# Dufferin Grove                          1
# Davenport                               1
# Little Italy                            1
# Little Portugal                         1
# Niagara                                 1
# The Junction                            1
# Church and Wellesley                    1
# North York City Centre                  1
# Hillcrest                               1
# Grange Park                             1
# Garden District                         1
# Discovery District                      1

# %% [markdown]
# Cluster 3:

# %%
data_clustered.loc[data_clustered['Cluster Labels'] == 2]
# Out:
#                          Income  Chinese Language Proportion        Lat  \
# Neighborhood
# The Beaches               67536                        0.007  43.671024
# Upper Beaches             44346                        0.007  43.671024
# Agincourt                 25750                        0.193  43.785353
# East Danforth             33847                        0.042  43.686360
# Riverdale                 40139                        0.067  43.665470
# Willowdale                39895                        0.079  43.769814
# Wexford                   28556                        0.000  43.745377
# St. James Town            22341                        0.000  43.669403
# Yorkville                105239                        0.000  43.671386
# Old East York             33172                        0.000  43.670862
# The Queensway             38944                        0.000  43.623618
# Financial District        63952                        0.000  43.648664
# Islington Six Points      43570                        0.000  43.642835
# Davisville                55735                        0.000  43.704312
# New Toronto               33415                        0.000  43.600763
# Fashion District          63282                        0.000  43.645456
# Earlscourt                26672                        0.000  43.676277
# Brockton                  27260                        0.000  43.650989
# Wychwood                  53613                        0.000  43.682094
# Harbord Village           45792                        0.000  43.661522
# Deer Park                 80704                        0.000  43.688090
# Newtonbrook               33428                        0.000  43.793886
# The Annex                 63636                        0.000  43.670338
# Scarborough City Centre   26756                        0.000  43.773077
# West Hill                 27936                        0.000  43.768914
# Bloor West Village        55578                        0.000  43.649318
# Cabbagetown               50398                        0.016  43.664473
# L'Amoreaux                26375                        0.139  43.796780
# Harbourfront/ CityPlace   69232                        0.024  43.640080
# Thorncliffe Park          25340                        0.000  43.704553
#
#                                Lon  Chinese Food Count  Total Food Count  \
# Neighborhood
# The Beaches             -79.296712                 1.0              26.0
# Upper Beaches           -79.296712                 1.0              26.0
# Agincourt               -79.278549                11.0              18.0
# East Danforth           -79.300316                 1.0              16.0
# Riverdale               -79.352594                 7.0              22.0
# Willowdale              -79.413810                 1.0              33.0
# Wexford                 -79.294715                 1.0              11.0
# St. James Town          -79.372704                 0.0              19.0
# Yorkville               -79.390168                 2.0              50.0
# Old East York           -79.372792                 0.0              20.0
# The Queensway           -79.514764                 1.0              17.0
# Financial District      -79.381534                 4.0              50.0
# Islington Six Points    -79.529706                 1.0              16.0
# Davisville              -79.388517                 2.0              34.0
# New Toronto             -79.505264                 1.0              17.0
# Fashion District        -79.394994                 1.0              50.0
# Earlscourt              -79.450572                 0.0              15.0
# Brockton                -79.440029                 0.0              16.0
# Wychwood                -79.423855                 1.0              38.0
# Harbord Village         -79.409745                 1.0              28.0
# Deer Park               -79.394093                 1.0              50.0
# Newtonbrook             -79.425679                 1.0              21.0
# The Annex               -79.407117                 1.0              37.0
# Scarborough City Centre -79.257774                 4.0              24.0
# West Hill               -79.187291                 1.0              20.0
# Bloor West Village      -79.484436                 0.0              23.0
# Cabbagetown             -79.366986                 2.0              43.0
# L'Amoreaux              -79.315761                 3.0              13.0
# Harbourfront/ CityPlace -79.380150                 3.0              50.0
# Thorncliffe Park        -79.345407                 1.0              15.0
#
#                          Cluster Labels
# Neighborhood
# The Beaches                           2
# Upper Beaches                         2
# Agincourt                             2
# East Danforth                         2
# Riverdale                             2
# Willowdale                            2
# Wexford                               2
# St. James Town                        2
# Yorkville                             2
# Old East York                         2
# The Queensway                         2
# Financial District                    2
# Islington Six Points                  2
# Davisville                            2
# New Toronto                           2
# Fashion District                      2
# Earlscourt                            2
# Brockton                              2
# Wychwood                              2
# Harbord Village                       2
# Deer Park                             2
# Newtonbrook                           2
# The Annex                             2
# Scarborough City Centre               2
# West Hill                             2
# Bloor West Village                    2
# Cabbagetown                           2
# L'Amoreaux                            2
# Harbourfront/ CityPlace               2
# Thorncliffe Park                      2

# %% [markdown]
# Cluster 4:

# %%
data_clustered.loc[data_clustered['Cluster Labels'] == 3]
# Out:
#                    Income  Chinese Language Proportion        Lat        Lon  \
# Neighborhood
# Kensington Market   23335                        0.143  43.655214 -79.402260
# Alexandra Park      19687                        0.179  43.650758 -79.404298
#
#                    Chinese Food Count  Total Food Count  Cluster Labels
# Neighborhood
# Kensington Market                 3.0              50.0               3
# Alexandra Park                    4.0              50.0               3
